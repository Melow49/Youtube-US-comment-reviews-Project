# %%
import pandas as pd
from sqlalchemy import create_engine


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
#open videos csv file

videos = pd.read_csv('./Resources/USvideos.csv',error_bad_lines=False)

videos.head()
# Out:
# b'Skipping line 2401: expected 11 fields, saw 21\nSkipping line 2800: expected 11 fields, saw 21\nSkipping line 5297: expected 11 fields, saw 12\nSkipping line 5299: expected 11 fields, saw 12\nSkipping line 5300: expected 11 fields, saw 12\nSkipping line 5301: expected 11 fields, saw 12\n'
#       video_id                                              title  \
# 0  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1  K4wEI5zhHB0            iPhone X — Introducing iPhone X — Apple
# 2  cLdxuaxaQwc                                        My Response
# 3  WYYvHb03Eog                          Apple iPhone X first look
# 4  sjlHnJvXdQs                                  iPhone X (parody)
#
#       channel_title  category_id  \
# 0  Logan Paul Vlogs           24
# 1             Apple           28
# 2         PewDiePie           22
# 3         The Verge           28
# 4        jacksfilms           23
#
#                                                 tags    views   likes  \
# 0  logan paul vlog|logan paul|logan|paul|olympics...  4394029  320053
# 1  Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lig...  7860119  185853
# 2                                             [none]  5845909  576597
# 3  apple iphone x hands on|Apple iPhone X|iPhone ...  2642103   24975
# 4  jacksfilms|parody|parodies|iphone|iphone x|iph...  1168130   96666
#
#    dislikes  comment_total                                  thumbnail_link  \
# 0      5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 1     26679              0  https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg
# 2     39774         170708  https://i.ytimg.com/vi/cLdxuaxaQwc/default.jpg
# 3      4542          12829  https://i.ytimg.com/vi/WYYvHb03Eog/default.jpg
# 4       568           6666  https://i.ytimg.com/vi/sjlHnJvXdQs/default.jpg
#
#     date
# 0  13.09
# 1  13.09
# 2  13.09
# 3  13.09
# 4  13.09

# %%
#open comments file 
comments = pd.read_csv('./Resources/UScomments.csv', error_bad_lines=False)
comments.head()
# Out:
# b'Skipping line 41589: expected 4 fields, saw 11\nSkipping line 51628: expected 4 fields, saw 7\nSkipping line 114465: expected 4 fields, saw 5\n'
# b'Skipping line 142496: expected 4 fields, saw 8\nSkipping line 189732: expected 4 fields, saw 6\nSkipping line 245218: expected 4 fields, saw 7\n'
# b'Skipping line 388430: expected 4 fields, saw 5\n'
# /Users/miladhazrati/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       video_id                                       comment_text likes  \
# 0  XpVt6Z1Gjjo                  Logan Paul it's yo big day ‼️‼️‼️     4
# 1  XpVt6Z1Gjjo  I've been following you from the start of your...     3
# 2  XpVt6Z1Gjjo                 Say hi to Kong and maverick for me     3
# 3  XpVt6Z1Gjjo                                MY FAN . attendance     3
# 4  XpVt6Z1Gjjo                                         trending 😉     3
#
#   replies
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
videos['category_id'] = videos['category_id'].astype(int)
videos.head()
# Out:
#       video_id                                              title  \
# 0  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1  K4wEI5zhHB0            iPhone X — Introducing iPhone X — Apple
# 2  cLdxuaxaQwc                                        My Response
# 3  WYYvHb03Eog                          Apple iPhone X first look
# 4  sjlHnJvXdQs                                  iPhone X (parody)
#
#       channel_title  category_id  \
# 0  Logan Paul Vlogs           24
# 1             Apple           28
# 2         PewDiePie           22
# 3         The Verge           28
# 4        jacksfilms           23
#
#                                                 tags    views   likes  \
# 0  logan paul vlog|logan paul|logan|paul|olympics...  4394029  320053
# 1  Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lig...  7860119  185853
# 2                                             [none]  5845909  576597
# 3  apple iphone x hands on|Apple iPhone X|iPhone ...  2642103   24975
# 4  jacksfilms|parody|parodies|iphone|iphone x|iph...  1168130   96666
#
#    dislikes  comment_total                                  thumbnail_link  \
# 0      5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 1     26679              0  https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg
# 2     39774         170708  https://i.ytimg.com/vi/cLdxuaxaQwc/default.jpg
# 3      4542          12829  https://i.ytimg.com/vi/WYYvHb03Eog/default.jpg
# 4       568           6666  https://i.ytimg.com/vi/sjlHnJvXdQs/default.jpg
#
#     date
# 0  13.09
# 1  13.09
# 2  13.09
# 3  13.09
# 4  13.09

# %%
#total comments by us customers
total_comment= videos["comment_total"].max()
total_comment
# Out:
# 736179

# %%
#merging both file into one 
youtube_df = pd.merge(videos, comments, on="video_id")
youtube_df.head()
# Out:
#       video_id                                              title  \
# 0  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 2  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 3  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 4  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
#
#       channel_title  category_id  \
# 0  Logan Paul Vlogs           24
# 1  Logan Paul Vlogs           24
# 2  Logan Paul Vlogs           24
# 3  Logan Paul Vlogs           24
# 4  Logan Paul Vlogs           24
#
#                                                 tags    views  likes_x  \
# 0  logan paul vlog|logan paul|logan|paul|olympics...  4394029   320053
# 1  logan paul vlog|logan paul|logan|paul|olympics...  4394029   320053
# 2  logan paul vlog|logan paul|logan|paul|olympics...  4394029   320053
# 3  logan paul vlog|logan paul|logan|paul|olympics...  4394029   320053
# 4  logan paul vlog|logan paul|logan|paul|olympics...  4394029   320053
#
#    dislikes  comment_total                                  thumbnail_link  \
# 0      5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 1      5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 2      5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 3      5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 4      5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
#
#     date                                       comment_text likes_y replies
# 0  13.09                  Logan Paul it's yo big day ‼️‼️‼️       4       0
# 1  13.09  I've been following you from the start of your...       3       0
# 2  13.09                 Say hi to Kong and maverick for me       3       0
# 3  13.09                                MY FAN . attendance       3       0
# 4  13.09                                         trending 😉       3       0

# %%
#convert the date in to regular format

youtube_df['date'] =  pd.to_datetime(youtube_df.date, format="%d.%m")
youtube_df.head()
# Out:
#       video_id                                              title  \
# 0  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 2  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 3  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 4  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
#
#       channel_title  category_id  \
# 0  Logan Paul Vlogs           24
# 1  Logan Paul Vlogs           24
# 2  Logan Paul Vlogs           24
# 3  Logan Paul Vlogs           24
# 4  Logan Paul Vlogs           24
#
#                                                 tags    views  likes_x  \
# 0  logan paul vlog|logan paul|logan|paul|olympics...  4394029   320053
# 1  logan paul vlog|logan paul|logan|paul|olympics...  4394029   320053
# 2  logan paul vlog|logan paul|logan|paul|olympics...  4394029   320053
# 3  logan paul vlog|logan paul|logan|paul|olympics...  4394029   320053
# 4  logan paul vlog|logan paul|logan|paul|olympics...  4394029   320053
#
#    dislikes  comment_total                                  thumbnail_link  \
# 0      5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 1      5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 2      5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 3      5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 4      5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
#
#         date                                       comment_text likes_y  \
# 0 1900-09-13                  Logan Paul it's yo big day ‼️‼️‼️       4
# 1 1900-09-13  I've been following you from the start of your...       3
# 2 1900-09-13                 Say hi to Kong and maverick for me       3
# 3 1900-09-13                                MY FAN . attendance       3
# 4 1900-09-13                                         trending 😉       3
#
#   replies
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
#rename all the column names

youtube_df = youtube_df.rename(columns={"video_id":"video_id",
                                        "title": "title",
                                      "channel_title": "channel",
                                      "category_id": "category",
                                      "tags": "tags",
                                      "views": "views",
                                      "likes_x":"likes",
                                      "dislikes": "dislike",
                                      "comment_total": "total-comment",
                                      "thumbnail_link": "thumbnail-links",
                                      "date": "date",
                                      "comment_text": "text-comments",
                                      "likes_y": "likes-y",
                                      "replies": "replies"
                                       })
youtube_df.head()
# Out:
#       video_id                                              title  \
# 0  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 2  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 3  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 4  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
#
#             channel  category  \
# 0  Logan Paul Vlogs        24
# 1  Logan Paul Vlogs        24
# 2  Logan Paul Vlogs        24
# 3  Logan Paul Vlogs        24
# 4  Logan Paul Vlogs        24
#
#                                                 tags    views   likes  \
# 0  logan paul vlog|logan paul|logan|paul|olympics...  4394029  320053
# 1  logan paul vlog|logan paul|logan|paul|olympics...  4394029  320053
# 2  logan paul vlog|logan paul|logan|paul|olympics...  4394029  320053
# 3  logan paul vlog|logan paul|logan|paul|olympics...  4394029  320053
# 4  logan paul vlog|logan paul|logan|paul|olympics...  4394029  320053
#
#    dislike  total-comment                                 thumbnail-links  \
# 0     5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 1     5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 2     5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 3     5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 4     5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
#
#         date                                      text-comments likes-y  \
# 0 1900-09-13                  Logan Paul it's yo big day ‼️‼️‼️       4
# 1 1900-09-13  I've been following you from the start of your...       3
# 2 1900-09-13                 Say hi to Kong and maverick for me       3
# 3 1900-09-13                                MY FAN . attendance       3
# 4 1900-09-13                                         trending 😉       3
#
#   replies
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
USVideo_Likes = youtube_df.sort_values('likes', ascending=False).drop_duplicates('video_id').sort_index()
USVideo_Likes.groupby('category').likes.mean().plot(kind="bar")
print(USVideo_Likes.groupby('category').likes.mean())
plt.title("Average Likes per Category")
plt.show()
# Out:
# category
# 1     22582.793814
# 2     13033.714286
# 10    68134.164134
# 15    16028.432432
# 17    12280.625899
# 19    12025.294118
# 20    21085.333333
# 22    33875.609756
# 23    56468.828571
# 24    29488.078603
# 25     4429.817143
# 26    29031.834615
# 27    17404.887640
# 28    18632.423611
# 29      411.000000
# 43      114.000000
# Name: likes, dtype: float64

# %%
#save it to output folder
youtube_df.to_csv("./Output/youtube.csv")

# %%
#creating csv file 1

table_1df= youtube_df[["video_id","title","channel","likes","dislike","category"]].copy()
table_1df.head()
# Out:
#       video_id                                              title  \
# 0  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 2  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 3  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 4  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
#
#             channel   likes  dislike  category
# 0  Logan Paul Vlogs  320053     5931        24
# 1  Logan Paul Vlogs  320053     5931        24
# 2  Logan Paul Vlogs  320053     5931        24
# 3  Logan Paul Vlogs  320053     5931        24
# 4  Logan Paul Vlogs  320053     5931        24

# %%
#save it to output folder

table_1df.to_csv("./Output/table_1df.csv")

# %%
#creating csv file 2 for comments, tags and number of views
table_2df = youtube_df[["category", "video_id","total-comment","thumbnail-links", "views", "tags", "text-comments"]].copy()
table_2df.head()
# Out:
#    category     video_id  total-comment  \
# 0        24  XpVt6Z1Gjjo          46245
# 1        24  XpVt6Z1Gjjo          46245
# 2        24  XpVt6Z1Gjjo          46245
# 3        24  XpVt6Z1Gjjo          46245
# 4        24  XpVt6Z1Gjjo          46245
#
#                                   thumbnail-links    views  \
# 0  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg  4394029
# 1  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg  4394029
# 2  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg  4394029
# 3  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg  4394029
# 4  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg  4394029
#
#                                                 tags  \
# 0  logan paul vlog|logan paul|logan|paul|olympics...
# 1  logan paul vlog|logan paul|logan|paul|olympics...
# 2  logan paul vlog|logan paul|logan|paul|olympics...
# 3  logan paul vlog|logan paul|logan|paul|olympics...
# 4  logan paul vlog|logan paul|logan|paul|olympics...
#
#                                        text-comments
# 0                  Logan Paul it's yo big day ‼️‼️‼️
# 1  I've been following you from the start of your...
# 2                 Say hi to Kong and maverick for me
# 3                                MY FAN . attendance
# 4                                         trending 😉

# %%
table_2df.to_csv("./Output/table_2df.csv")

# %%
#separate data set for categories and number of likes

table_3df = youtube_df[["category", "text-comments","likes-y", "replies","date", "likes"]].copy()
table_3df.head()
# Out:
#    category                                      text-comments likes-y  \
# 0        24                  Logan Paul it's yo big day ‼️‼️‼️       4
# 1        24  I've been following you from the start of your...       3
# 2        24                 Say hi to Kong and maverick for me       3
# 3        24                                MY FAN . attendance       3
# 4        24                                         trending 😉       3
#
#   replies       date   likes
# 0       0 1900-09-13  320053
# 1       0 1900-09-13  320053
# 2       0 1900-09-13  320053
# 3       0 1900-09-13  320053
# 4       0 1900-09-13  320053

# %%
#save it to output folder

table_3df.to_csv("./Output/table_3df.csv")

# %%
#connect to pdadmin 

rds_connection_string = "postgres:password@127.0.0.1/etl-db"
engine = create_engine(f'postgres://{rds_connection_string}')
# Out:
# /Users/miladhazrati/anaconda3/lib/python3.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
#added the table to pgadmin
table_1df.to_sql(name='youtube', con=engine, if_exists='append', index=False)

# %%
#added 2nd table to pgadmin
table_2df.to_sql(name='comments', con=engine, if_exists='append', index=False)

# %%
#added 3rd table to pdadmin
table_3df.to_sql(name='category', con=engine, if_exists='append', index=False)

# %%
#successful to read the data set directly from pgadmin


pd.read_sql_query('select * from youtube', con=engine).head()
# Out:
#       video_id                                              title  \
# 0  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 2  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 3  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 4  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
#
#             channel   likes  dislike  category
# 0  Logan Paul Vlogs  320053     5931        24
# 1  Logan Paul Vlogs  320053     5931        24
# 2  Logan Paul Vlogs  320053     5931        24
# 3  Logan Paul Vlogs  320053     5931        24
# 4  Logan Paul Vlogs  320053     5931        24

# %%
#reading 2nd dataset from pgadmin


pd.read_sql_query('select * from comments', con=engine).head()
# Out:
#    category     video_id  total-comment  \
# 0        24  XpVt6Z1Gjjo          46245
# 1        24  XpVt6Z1Gjjo          46245
# 2        24  XpVt6Z1Gjjo          46245
# 3        24  XpVt6Z1Gjjo          46245
# 4        24  XpVt6Z1Gjjo          46245
#
#                                   thumbnail-links    views  \
# 0  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg  4394029
# 1  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg  4394029
# 2  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg  4394029
# 3  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg  4394029
# 4  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg  4394029
#
#                                                 tags  \
# 0  logan paul vlog|logan paul|logan|paul|olympics...
# 1  logan paul vlog|logan paul|logan|paul|olympics...
# 2  logan paul vlog|logan paul|logan|paul|olympics...
# 3  logan paul vlog|logan paul|logan|paul|olympics...
# 4  logan paul vlog|logan paul|logan|paul|olympics...
#
#                                        text-comments
# 0                  Logan Paul it's yo big day ‼️‼️‼️
# 1  I've been following you from the start of your...
# 2                 Say hi to Kong and maverick for me
# 3                                MY FAN . attendance
# 4                                         trending 😉

# %%
#Reading category dataset from pgadmin


pd.read_sql_query('select * from category', con=engine).head()
# Out:
#    category                                      text-comments likes-y  \
# 0        24                  Logan Paul it's yo big day ‼️‼️‼️       4
# 1        24  I've been following you from the start of your...       3
# 2        24                 Say hi to Kong and maverick for me       3
# 3        24                                MY FAN . attendance       3
# 4        24                                         trending 😉       3
#
#   replies       date   likes
# 0       0 1900-09-13  320053
# 1       0 1900-09-13  320053
# 2       0 1900-09-13  320053
# 3       0 1900-09-13  320053
# 4       0 1900-09-13  320053
